# %%
import pandas as pd
import datetime as dt

# %%
#The goal of this file is to create a dataset of reservations made for 2016-2020 (May 1 - September 30) 
#for Pacific NorthWest (Washington, Oregon, California)

#Because of a large size of the dataset (exceeds limits of GitHub repo) cleaning and merging was done on a local computer

# %%
#Reading the data for 2016
data2016 = pd.read_csv("../../Resources/data/reservations2016.csv", encoding= 'unicode_escape')
data2016
# Out:
#          HistoricalReservationID OrderNumber Agency  OrgID  \
# 0                     2078081704  2-32732134  USACE    130
# 1                     2078083331  2-32732551   USFS    131
# 2                     2078083497  2-32732552   USFS    131
# 3                     2078083555   4-3155416    NPS    128
# 4                     2078083581  2-32732553   USFS    131
# ...                          ...         ...    ...    ...
# 2980709               2434322908   6-3050956    NPS    128
# 2980710               2434323098   4-3698992    NPS    128
# 2980711               2434324894  2-36683621    NPS    128
# 2980712               2434324927  2-36683622    NPS    128
# 2980713               2434325007  2-36683623  USACE    130
#
#                              CodeHierarchy RegionCode  \
# 0        |1|70902|74304|74350|74559|71075|  CH3013280
# 1        |1|70903|72602|74411|74812|70392|     F50755
# 2        |1|70903|72602|74416|72724|75429|     F51753
# 3              |1|70904|74324|77803|77813|  CAVE-7170
# 4        |1|70903|74311|74387|72667|70468|     F30406
# ...                                    ...        ...
# 2980709        |1|70904|74325|74274|70853|  CAHA-5190
# 2980710       |1|70904|74327|74292|135840|  SEKI-8550
# 2980711        |1|70904|74324|74297|70923|  ZION-1590
# 2980712        |1|70904|74324|74282|70971|  GRCA-8210
# 2980713  |1|70902|74304|74349|74547|73073|  CH2000970
#
#                               RegionDescription  ParentLocationID  \
# 0                              OLD HICKORY LAKE             74350
# 1                                  OJAI RD - FS             74411
# 2                             YUBA RIVER RD -FS             74416
# 3                Carlsbad Caverns National Park             74324
# 4                              RED ROCK RD  -FS             74387
# ...                                         ...               ...
# 2980709         Cape Hatteras National Seashore             74325
# 2980710  Sequoia and Kings Canyon National Park             74327
# 2980711                      Zion National Park             74324
# 2980712              Grand Canyon National Park             74324
# 2980713                       BARREN RIVER LAKE             74349
#
#                ParentLocation  LegacyFacilityID  ... Truck Bus Bicycle  \
# 0          NASHVILLE DISTRICT             71075  ...   NaN NaN     NaN
# 1           LOS PADRES NF -FS             70392  ...   NaN NaN     NaN
# 2               TAHOE NF - FS             75429  ...   NaN NaN     NaN
# 3        Intermountain Region             77813  ...   NaN NaN     NaN
# 4            COCONINO NF - FS             70468  ...   NaN NaN     NaN
# ...                       ...               ...  ...   ...  ..     ...
# 2980709      Southeast Region             70853  ...   NaN NaN     NaN
# 2980710   Pacific West Region            135840  ...   NaN NaN     NaN
# 2980711  Intermountain Region             70923  ...   NaN NaN     NaN
# 2980712  Intermountain Region             70971  ...   NaN NaN     NaN
# 2980713      LOUISVILLE DIST.             73073  ...   NaN NaN     NaN
#
#          Snowmobile OffRoadlAllTerrainVehicle  PowerBoat  PickupCamper  \
# 0               NaN                       NaN        NaN           NaN
# 1               NaN                       NaN        NaN           NaN
# 2               NaN                       NaN        NaN           NaN
# 3               NaN                       NaN        NaN           NaN
# 4               NaN                       NaN        NaN           NaN
# ...             ...                       ...        ...           ...
# 2980709         NaN                       NaN        NaN           NaN
# 2980710         NaN                       NaN        NaN           NaN
# 2980711         NaN                       NaN        NaN           NaN
# 2980712         NaN                       NaN        NaN           NaN
# 2980713         NaN                       NaN        NaN           NaN
#
#         LargeTentOver9x12 SmallTent  Marinaboat
# 0                     NaN       NaN         NaN
# 1                     NaN       NaN         NaN
# 2                     NaN       NaN         NaN
# 3                     NaN       NaN         NaN
# 4                     NaN       NaN         NaN
# ...                   ...       ...         ...
# 2980709               NaN       NaN         NaN
# 2980710               NaN       NaN         NaN
# 2980711               NaN       NaN         NaN
# 2980712               NaN       NaN         NaN
# 2980713               NaN       NaN         NaN
#
# [2980714 rows x 56 columns]

# %%
#Checking columns
data2016.columns
# Out:
# Index(['HistoricalReservationID', 'OrderNumber', 'Agency', 'OrgID',
#        'CodeHierarchy', 'RegionCode', 'RegionDescription', 'ParentLocationID',
#        'ParentLocation', 'LegacyFacilityID', 'Park', 'SiteType', 'UseType',
#        'ProductID', 'EntityType', 'EntityID', 'FacilityID', 'FacilityZIP',
#        'FacilityState', 'FacilityLongitude', 'FacilityLatitude', 'CustomerZIP',
#        'CustomerState', 'CustomerCountry', 'Tax', 'UseFee', 'TranFee',
#        'AttrFee', 'TotalBeforeTax', 'TotalPaid', 'StartDate', 'EndDate',
#        'OrderDate', 'NumberOfPeople', 'Tent', 'Popup', 'Trailer',
#        'RVMotorhome', 'Boat', 'HorseTrailer', 'Car', 'FifthWheel', 'Van',
#        'CanoeKayak', 'BoatTrailer', 'Motorcycle', 'Truck', 'Bus', 'Bicycle',
#        'Snowmobile', 'OffRoadlAllTerrainVehicle', 'PowerBoat', 'PickupCamper',
#        'LargeTentOver9x12', 'SmallTent', 'Marinaboat'],
#       dtype='object')

# %%
#Choosing only West Coast states data
data2016_WestCoast = data2016.loc[(data2016["FacilityState"] == "Oregon") |
                                  (data2016["FacilityState"] == "OR") |
                                  (data2016["FacilityState"] == "Washington") |
                                  (data2016["FacilityState"] == "WA") |
                                  (data2016["FacilityState"] == "California") |
                                  (data2016["FacilityState"] == "CA")]

# %%
#For the purposes of the project we interested only in reservable overnight campsites, but the reservation data also 
#included other types of camgrounds services

data2016_WestCoast["EntityType"].unique()
# Out:
# array(['Site', 'Entrance', 'Tour', 'POS'], dtype=object)

# %%
data2016_WestCoast["UseType"].unique()
# Out:
# array(['Overnight', 'Day', 'None'], dtype=object)

# %%
#Choosing only reservable overnight campsites

data2016_WestCoast_clean = data2016_WestCoast.loc[(data2016_WestCoast["UseType"] == "Overnight") & 
                                                  (data2016_WestCoast["EntityType"] == "Site")]

# %%
#Dropping unnecessary columns

data2016_WestCoast_clean = data2016_WestCoast_clean.drop(columns=['HistoricalReservationID', 
       'OrderNumber', 'OrgID', 'CodeHierarchy', 'RegionCode', 'ParentLocationID',
       'LegacyFacilityID', 'UseType', 'ProductID', 'EntityType', 'EntityID',
       'FacilityLongitude', 'FacilityLatitude', 'Tax', 'UseFee', 'TranFee',
       'AttrFee', 'TotalPaid', 'Tent', 'Popup', 'Trailer',
       'RVMotorhome', 'Boat', 'HorseTrailer', 'Car', 'FifthWheel', 'Van',
       'CanoeKayak', 'BoatTrailer', 'Motorcycle', 'Truck', 'Bus', 'Bicycle',
       'Snowmobile', 'OffRoadlAllTerrainVehicle', 'PowerBoat', 'PickupCamper',
       'LargeTentOver9x12', 'SmallTent', 'Marinaboat'])

# %%
#Checking datatypes for future manipulations
data2016_WestCoast_clean.dtypes
# Out:
# Agency                object
# RegionDescription     object
# ParentLocation        object
# Park                  object
# SiteType              object
# FacilityID           float64
# FacilityZIP           object
# FacilityState         object
# CustomerZIP           object
# CustomerState         object
# CustomerCountry       object
# TotalBeforeTax       float64
# StartDate             object
# EndDate               object
# OrderDate             object
# NumberOfPeople         int64
# dtype: object

# %%
#Converting dates to datetime data type with purpose extract data for the camping season (May 1 - September 30)
data2016_WestCoast_clean["StartDate"] = pd.to_datetime(data2016_WestCoast_clean["StartDate"])
data2016_WestCoast_clean["EndDate"] = pd.to_datetime(data2016_WestCoast_clean["EndDate"])
data2016_WestCoast_clean["OrderDate"] = pd.to_datetime(data2016_WestCoast_clean["OrderDate"])

# %%
#Checking the success of converting the date data
data2016_WestCoast_clean.dtypes
# Out:
# Agency                       object
# RegionDescription            object
# ParentLocation               object
# Park                         object
# SiteType                     object
# FacilityID                  float64
# FacilityZIP                  object
# FacilityState                object
# CustomerZIP                  object
# CustomerState                object
# CustomerCountry              object
# TotalBeforeTax              float64
# StartDate            datetime64[ns]
# EndDate              datetime64[ns]
# OrderDate            datetime64[ns]
# NumberOfPeople                int64
# dtype: object

# %%
#Extracting camping season data
data2016_WestCoast_clean = data2016_WestCoast_clean.loc[(data2016_WestCoast_clean["StartDate"] >= "2016-05-01") 
                                                      & (data2016_WestCoast_clean["EndDate"] <= "2016-09-30")]
data2016_WestCoast_clean
# Out:
#         Agency          RegionDescription               ParentLocation  \
# 48         NPS  Joshua Tree National Park          Pacific West Region
# 96        USFS            MAMMOTH RD - FS                 INYO NF - FS
# 99        USFS  LOS ANGELES RIVER RD - FS              ANGELES NF - FS
# 243       USFS             NACHES RD - FS  OKANOGAN - WENATCHEE NF -FS
# 274      USACE             LAKE MENDOCINO           SAN FRANCISCO DIST
# ...        ...                        ...                          ...
# 2976217  USACE                LAKE KAWEAH             SACRAMENTO DIST.
# 2976234  USACE               SUCCESS LAKE             SACRAMENTO DIST.
# 2976244  USACE               SUCCESS LAKE             SACRAMENTO DIST.
# 2976246  USACE                LAKE KAWEAH             SACRAMENTO DIST.
# 2976299   USFS       LAKE TAHOE BASIN -FS       LAKE TAHOE BASIN  - FS
#
#                             Park                          SiteType  \
# 48              SHEEP PASS GROUP  GROUP TENT ONLY AREA NONELECTRIC
# 96        PUMICE FLAT GROUP CAMP        GROUP STANDARD NONELECTRIC
# 99       MEADOW GROUP CAMPGROUND        GROUP STANDARD NONELECTRIC
# 243       SALMON COVE GROUP SITE   GROUP STANDARD AREA NONELECTRIC
# 274       BUSHAY RECREATION AREA        GROUP STANDARD NONELECTRIC
# ...                          ...                               ...
# 2976217              HORSE CREEK              STANDARD NONELECTRIC
# 2976234                     TULE                 STANDARD ELECTRIC
# 2976244                     TULE                 STANDARD ELECTRIC
# 2976246              HORSE CREEK              STANDARD NONELECTRIC
# 2976299  WILLIAM KENT CAMPGROUND              STANDARD NONELECTRIC
#
#          FacilityID FacilityZIP FacilityState CustomerZIP CustomerState  \
# 48         232470.0  92277-3597            CA       90027            CA
# 96         231957.0       94301            CA       92301            CA
# 99         233366.0         NaN            CA       91701            CA
# 243        234498.0       98937            WA       98942            WA
# 274        233437.0  95482-9404            CA       94565            CA
# ...             ...         ...           ...         ...           ...
# 2976217    233692.0  93244-4270            CA       93244            CA
# 2976234    233655.0         NaN            CA     unknown            CA
# 2976244    233655.0         NaN            CA     unknown            CA
# 2976246    233692.0  93244-4270            CA       93292            CA
# 2976299    232874.0       94301            CA       98122            WA
#
#         CustomerCountry  TotalBeforeTax  StartDate    EndDate  OrderDate  \
# 48                  USA          100.00 2016-09-03 2016-09-05 2015-10-01
# 96                  USA          313.05 2016-06-30 2016-07-03 2015-10-01
# 99                  USA           81.00 2016-06-24 2016-06-26 2015-10-01
# 243                 USA          159.00 2016-09-08 2016-09-11 2015-10-01
# 274                 USA          705.00 2016-09-02 2016-09-05 2015-10-01
# ...                 ...             ...        ...        ...        ...
# 2976217             USA           10.00 2016-09-23 2016-09-24 2016-09-30
# 2976234             USA           15.00 2016-09-26 2016-09-27 2016-09-30
# 2976244             USA           15.00 2016-09-27 2016-09-28 2016-09-30
# 2976246             USA            0.00 2016-09-27 2016-09-28 2016-09-30
# 2976299             USA           28.00 2016-09-29 2016-09-30 2016-09-30
#
#          NumberOfPeople
# 48                   20
# 96                   30
# 99                   24
# 243                  27
# 274                  40
# ...                 ...
# 2976217               2
# 2976234               2
# 2976244               2
# 2976246               3
# 2976299               2
#
# [509372 rows x 16 columns]

# %%
#Reading the data for 2017
data2017 = pd.read_csv("../../Resources/data/reservations2017.csv", encoding= 'unicode_escape')
data2017
# Out:
#          HistoricalReservationID OrderNumber Agency  OrgID  \
# 0                     2434304548  2-36681755   USFS    131
# 1                     2434322404   4-3699000    NPS    128
# 2                     2434322425   4-3699001    NPS    128
# 3                     2434322473   4-3699002    NPS    128
# 4                     2434322626  2-36683841    NPS    128
# ...                          ...         ...    ...    ...
# 3303548               2830803631   4-4180361    NPS    128
# 3303549               2830803653   4-4180362    NPS    128
# 3303550               2830803670  2-39280451    NPS    128
# 3303551               2830803705  2-39280452  USACE    130
# 3303552               2830804361   4-4180282    NPS    128
#
#                              CodeHierarchy RegionCode  \
# 0        |1|70903|72601|72630|72684|71879|     F00531
# 1              |1|70904|74268|77805|77815|  INDE-4450
# 2              |1|70904|74327|72368|72369|       VALR
# 3             |1|70904|74327|74292|135840|  SEKI-8550
# 4              |1|70904|74324|74282|70971|  GRCA-8210
# ...                                    ...        ...
# 3303548        |1|70904|74327|72368|72369|       VALR
# 3303549        |1|70904|74327|72368|72369|       VALR
# 3303550        |1|70904|74324|74282|70971|  GRCA-8210
# 3303551  |1|70902|74306|74358|74590|73251|  CL3004990
# 3303552        |1|70904|74324|77803|77813|  CAVE-7170
#
#                               RegionDescription  ParentLocationID  \
# 0                                 SITKA RD - FS             72630
# 1         Independence National Historical Park             74268
# 2             World War II Valor in the Pacific             74327
# 3        Sequoia and Kings Canyon National Park             74327
# 4                    Grand Canyon National Park             74324
# ...                                         ...               ...
# 3303548       World War II Valor in the Pacific             74327
# 3303549       World War II Valor in the Pacific             74327
# 3303550              Grand Canyon National Park             74324
# 3303551                             LAKE SONOMA             74358
# 3303552          Carlsbad Caverns National Park             74324
#
#                ParentLocation  LegacyFacilityID  ... Truck Bus Bicycle  \
# 0             TONGASS NF - FS             71879  ...   NaN NaN     NaN
# 1            Northeast Region             77815  ...   NaN NaN     NaN
# 2         Pacific West Region             72369  ...   NaN NaN     NaN
# 3         Pacific West Region            135840  ...   NaN NaN     NaN
# 4        Intermountain Region             70971  ...   NaN NaN     NaN
# ...                       ...               ...  ...   ...  ..     ...
# 3303548   Pacific West Region             72369  ...   NaN NaN     NaN
# 3303549   Pacific West Region             72369  ...   NaN NaN     NaN
# 3303550  Intermountain Region             70971  ...   NaN NaN     NaN
# 3303551    SAN FRANCISCO DIST             73251  ...   NaN NaN     NaN
# 3303552  Intermountain Region             77813  ...   NaN NaN     NaN
#
#          Snowmobile OffRoadlAllTerrainVehicle  PowerBoat  PickupCamper  \
# 0               NaN                       NaN        NaN           NaN
# 1               NaN                       NaN        NaN           NaN
# 2               NaN                       NaN        NaN           NaN
# 3               NaN                       NaN        NaN           NaN
# 4               NaN                       NaN        NaN           NaN
# ...             ...                       ...        ...           ...
# 3303548         NaN                       NaN        NaN           NaN
# 3303549         NaN                       NaN        NaN           NaN
# 3303550         NaN                       NaN        NaN           NaN
# 3303551         NaN                       NaN        NaN           NaN
# 3303552         NaN                       NaN        NaN           NaN
#
#         LargeTentOver9x12 SmallTent  Marinaboat
# 0                     NaN       NaN         NaN
# 1                     NaN       NaN         NaN
# 2                     NaN       NaN         NaN
# 3                     NaN       NaN         NaN
# 4                     1.0       NaN         NaN
# ...                   ...       ...         ...
# 3303548               NaN       NaN         NaN
# 3303549               NaN       NaN         NaN
# 3303550               NaN       NaN         NaN
# 3303551               NaN       NaN         NaN
# 3303552               NaN       NaN         NaN
#
# [3303553 rows x 56 columns]

# %%
#Checking columns
data2017.columns
# Out:
# Index(['HistoricalReservationID', 'OrderNumber', 'Agency', 'OrgID',
#        'CodeHierarchy', 'RegionCode', 'RegionDescription', 'ParentLocationID',
#        'ParentLocation', 'LegacyFacilityID', 'Park', 'SiteType', 'UseType',
#        'ProductID', 'EntityType', 'EntityID', 'FacilityID', 'FacilityZIP',
#        'FacilityState', 'FacilityLongitude', 'FacilityLatitude', 'CustomerZIP',
#        'CustomerState', 'CustomerCountry', 'Tax', 'UseFee', 'TranFee',
#        'AttrFee', 'TotalBeforeTax', 'TotalPaid', 'StartDate', 'EndDate',
#        'OrderDate', 'NumberOfPeople', 'Tent', 'Popup', 'Trailer',
#        'RVMotorhome', 'Boat', 'HorseTrailer', 'Car', 'FifthWheel', 'Van',
#        'CanoeKayak', 'BoatTrailer', 'Motorcycle', 'Truck', 'Bus', 'Bicycle',
#        'Snowmobile', 'OffRoadlAllTerrainVehicle', 'PowerBoat', 'PickupCamper',
#        'LargeTentOver9x12', 'SmallTent', 'Marinaboat'],
#       dtype='object')

# %%
#Choosing only West Coast states data
data2017_WestCoast = data2017.loc[(data2017["FacilityState"] == "Oregon") |
                                  (data2017["FacilityState"] == "OR") |
                                  (data2017["FacilityState"] == "Washington") |
                                  (data2017["FacilityState"] == "WA") |
                                  (data2017["FacilityState"] == "California") |
                                  (data2017["FacilityState"] == "CA")]

# %%
#For the purposes of the project we interested only in reservable overnight campsites, but the reservation data also 
#included other types of camgrounds services
data2017_WestCoast["UseType"].unique()
# Out:
# array(['Overnight', 'None', 'Day'], dtype=object)

# %%
data2017_WestCoast["EntityType"].unique()
# Out:
# array(['Tour', 'Site', 'POS', 'Entrance'], dtype=object)

# %%
#Choosing only reservable overnight campsites
data2017_WestCoast_clean = data2017_WestCoast.loc[(data2017_WestCoast["UseType"] == "Overnight") 
                                                & (data2017_WestCoast["EntityType"] == "Site")]

# %%
#Dropping unnecessary columns
data2017_WestCoast_clean = data2017_WestCoast_clean.drop(columns=['HistoricalReservationID', 
       'OrderNumber', 'OrgID', 'CodeHierarchy', 'RegionCode', 'ParentLocationID',
       'LegacyFacilityID', 'UseType', 'ProductID', 'EntityType', 'EntityID',
       'FacilityLongitude', 'FacilityLatitude', 'Tax', 'UseFee', 'TranFee',
       'AttrFee', 'TotalPaid', 'Tent', 'Popup', 'Trailer',
       'RVMotorhome', 'Boat', 'HorseTrailer', 'Car', 'FifthWheel', 'Van',
       'CanoeKayak', 'BoatTrailer', 'Motorcycle', 'Truck', 'Bus', 'Bicycle',
       'Snowmobile', 'OffRoadlAllTerrainVehicle', 'PowerBoat', 'PickupCamper',
       'LargeTentOver9x12', 'SmallTent', 'Marinaboat'])

# %%
#Checking datatypes for future manipulations
data2017_WestCoast_clean.dtypes
# Out:
# Agency                object
# RegionDescription     object
# ParentLocation        object
# Park                  object
# SiteType              object
# FacilityID           float64
# FacilityZIP           object
# FacilityState         object
# CustomerZIP           object
# CustomerState         object
# CustomerCountry       object
# TotalBeforeTax       float64
# StartDate             object
# EndDate               object
# OrderDate             object
# NumberOfPeople         int64
# dtype: object

# %%
#Converting dates to datetime data type with purpose extract data for the camping season (May 1 - September 30)
data2017_WestCoast_clean["StartDate"] = pd.to_datetime(data2017_WestCoast_clean["StartDate"])
data2017_WestCoast_clean["EndDate"] = pd.to_datetime(data2017_WestCoast_clean["EndDate"])
data2017_WestCoast_clean["OrderDate"] = pd.to_datetime(data2017_WestCoast_clean["OrderDate"])

# %%
#Checking the success of converting the date data
data2017_WestCoast_clean.dtypes
# Out:
# Agency                       object
# RegionDescription            object
# ParentLocation               object
# Park                         object
# SiteType                     object
# FacilityID                  float64
# FacilityZIP                  object
# FacilityState                object
# CustomerZIP                  object
# CustomerState                object
# CustomerCountry              object
# TotalBeforeTax              float64
# StartDate            datetime64[ns]
# EndDate              datetime64[ns]
# OrderDate            datetime64[ns]
# NumberOfPeople                int64
# dtype: object

# %%
#Extracting camping season data
data2017_WestCoast_clean = data2017_WestCoast_clean.loc[(data2017_WestCoast_clean["StartDate"] >= "2017-05-01") 
                                                      & (data2017_WestCoast_clean["EndDate"] <= "2017-09-30")]
data2017_WestCoast_clean
# Out:
#         Agency          RegionDescription           ParentLocation  \
# 55         NPS      Olympic National Park      Pacific West Region
# 109       USFS           MONTEREY RD - FS        LOS PADRES NF -FS
# 234       USFS           MT ADAMS RD - FS  GIFFORD PINCHOT NF - FS
# 286        NPS  Joshua Tree National Park      Pacific West Region
# 764        NPS  Joshua Tree National Park      Pacific West Region
# ...        ...                        ...                      ...
# 3299676   USFS         HIGH SIERRA RD -FS           SIERRA NF - FS
# 3300287  USACE               HENSLEY LAKE         SACRAMENTO DIST.
# 3300326  USACE               HENSLEY LAKE         SACRAMENTO DIST.
# 3300335  USACE               HENSLEY LAKE         SACRAMENTO DIST.
# 3300521   USFS          MONO LAKE RD - FS             INYO NF - FS
#
#                                           Park  \
# 55       SOL DUC HOT SPRINGS RESORT CAMPGROUND
# 109                                ARROYO SECO
# 234                          Beaver Campground
# 286                           SHEEP PASS GROUP
# 764                     INDIAN COVE CAMPGROUND
# ...                                        ...
# 3299676                           DINKEY CREEK
# 3300287                            HIDDEN VIEW
# 3300326                            HIDDEN VIEW
# 3300335                            HIDDEN VIEW
# 3300521                               OH RIDGE
#
#                                  SiteType  FacilityID FacilityZIP  \
# 55                   STANDARD NONELECTRIC    251906.0         NaN
# 109            GROUP STANDARD NONELECTRIC    231958.0         NaN
# 234            GROUP STANDARD NONELECTRIC    232864.0         NaN
# 286      GROUP TENT ONLY AREA NONELECTRIC    232470.0  92277-3597
# 764      GROUP TENT ONLY AREA NONELECTRIC    232472.0  92277-3597
# ...                                   ...         ...         ...
# 3299676             TENT ONLY NONELECTRIC    232136.0       94301
# 3300287              STANDARD NONELECTRIC    233509.0         NaN
# 3300326                 STANDARD ELECTRIC    233509.0         NaN
# 3300335              STANDARD NONELECTRIC    233509.0         NaN
# 3300521              STANDARD NONELECTRIC    232269.0       94301
#
#         FacilityState CustomerZIP CustomerState CustomerCountry  \
# 55                 WA       97202            OR             USA
# 109                CA       93907            CA             USA
# 234                WA       98606            WA             USA
# 286                CA       92694            CA             USA
# 764                CA       90065            CA             USA
# ...               ...         ...           ...             ...
# 3299676            CA       93727            CA             USA
# 3300287            CA       93635            CA             USA
# 3300326            CA       95348            CA             USA
# 3300335            CA       93653            CA             USA
# 3300521            CA       91701            CA             USA
#
#          TotalBeforeTax  StartDate    EndDate  OrderDate  NumberOfPeople
# 55                69.00 2017-07-01 2017-07-04 2016-10-01               8
# 109              159.00 2017-07-14 2017-07-16 2016-10-01              20
# 234               19.00 2017-08-03 2017-08-06 2016-10-01              40
# 286               60.00 2017-09-01 2017-09-04 2016-10-01               8
# 764              100.00 2017-09-22 2017-09-24 2016-10-01              20
# ...                 ...        ...        ...        ...             ...
# 3299676           31.50 2017-09-29 2017-09-30 2017-09-30               5
# 3300287           20.00 2017-09-29 2017-09-30 2017-09-30               8
# 3300326           15.00 2017-09-29 2017-09-30 2017-09-30               1
# 3300335           20.00 2017-09-29 2017-09-30 2017-09-30               8
# 3300521           24.55 2017-09-29 2017-09-30 2017-09-30               1
#
# [555752 rows x 16 columns]

# %%
#Reading the data for 2018
data2018 = pd.read_csv("../../Resources/data/reservations2018.csv", encoding= 'unicode_escape')
data2018
# Out:
# D:\anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3072: DtypeWarning: Columns (12,17,29,31,55) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#          HistoricalReservationID OrderNumber Agency  OrgID  \
# 0                     2976269875   4-4358197    NPS  128.0
# 1                     2976269875   4-4358197    NPS  128.0
# 2                     2976269875   4-4358197    NPS  128.0
# 3                     2976371845   4-4358345    NPS  128.0
# 4                     2976358486   4-4358374    NPS  128.0
# ...                          ...         ...    ...    ...
# 3299800               3221486652   6-3833254    NPS  128.0
# 3299801               3221486652   6-3833254    NPS  128.0
# 3299802               3221486652   6-3833254    NPS  128.0
# 3299803               3221486652   6-3833254    NPS  128.0
# 3299804               3221486652   6-3833254    NPS  128.0
#
#                        CodeHierarchy RegionCode  \
# 0        |1|70904|74265|70710|70711|  KLGO-9825
# 1        |1|70904|74265|70710|70711|  KLGO-9825
# 2        |1|70904|74265|70710|70711|  KLGO-9825
# 3        |1|70904|74265|70710|70711|  KLGO-9825
# 4        |1|70904|74265|70710|70711|  KLGO-9825
# ...                              ...        ...
# 3299800  |1|70904|74322|74995|74996|  APIS-6140
# 3299801  |1|70904|74322|74995|74996|  APIS-6140
# 3299802  |1|70904|74322|74995|74996|  APIS-6140
# 3299803  |1|70904|74322|74995|74996|  APIS-6140
# 3299804  |1|70904|74322|74995|74996|  APIS-6140
#
#                                    RegionDescription  ParentLocationID  \
# 0        Klondike Gold Rush National Historical Park             74265
# 1        Klondike Gold Rush National Historical Park             74265
# 2        Klondike Gold Rush National Historical Park             74265
# 3        Klondike Gold Rush National Historical Park             74265
# 4        Klondike Gold Rush National Historical Park             74265
# ...                                              ...               ...
# 3299800           Apostle Islands National Lakeshore             74322
# 3299801           Apostle Islands National Lakeshore             74322
# 3299802           Apostle Islands National Lakeshore             74322
# 3299803           Apostle Islands National Lakeshore             74322
# 3299804           Apostle Islands National Lakeshore             74322
#
#          ParentLocation  LegacyFacilityID  ... Bus Bicycle Snowmobile  \
# 0         Alaska Region             70711  ... NaN     NaN        NaN
# 1         Alaska Region             70711  ... NaN     NaN        NaN
# 2         Alaska Region             70711  ... NaN     NaN        NaN
# 3         Alaska Region             70711  ... NaN     NaN        NaN
# 4         Alaska Region             70711  ... NaN     NaN        NaN
# ...                 ...               ...  ...  ..     ...        ...
# 3299800  Midwest Region             74996  ... NaN     NaN        NaN
# 3299801  Midwest Region             74996  ... NaN     NaN        NaN
# 3299802  Midwest Region             74996  ... NaN     NaN        NaN
# 3299803  Midwest Region             74996  ... NaN     NaN        NaN
# 3299804  Midwest Region             74996  ... NaN     NaN        NaN
#
#          OffRoadlAllTerrainVehicle PowerBoat  PickupCamper  LargeTentOver9x12  \
# 0                              NaN       NaN           NaN                NaN
# 1                              NaN       NaN           NaN                NaN
# 2                              NaN       NaN           NaN                NaN
# 3                              NaN       NaN           NaN                NaN
# 4                              NaN       NaN           NaN                NaN
# ...                            ...       ...           ...                ...
# 3299800                        NaN       NaN           NaN                NaN
# 3299801                        NaN       NaN           NaN                NaN
# 3299802                        NaN       NaN           NaN                NaN
# 3299803                        NaN       NaN           NaN                NaN
# 3299804                        NaN       NaN           NaN                NaN
#
#         SmallTent Marinaboat  \
# 0             NaN        NaN
# 1             NaN        NaN
# 2             NaN        NaN
# 3             NaN        NaN
# 4             NaN        NaN
# ...           ...        ...
# 3299800       NaN        NaN
# 3299801       NaN        NaN
# 3299802       NaN        NaN
# 3299803       NaN        NaN
# 3299804       NaN        NaN
#
#                                               LatLongPoint
# 0        <e6100000 010cabaa aaaaaaba 4d40610b b6600bea ...
# 1        <e6100000 010cabaa aaaaaaba 4d40610b b6600bea ...
# 2        <e6100000 010cabaa aaaaaaba 4d40610b b6600bea ...
# 3        <e6100000 010cabaa aaaaaaba 4d40610b b6600bea ...
# 4        <e6100000 010cabaa aaaaaaba 4d40610b b6600bea ...
# ...                                                    ...
# 3299800  <e6100000 010c8888 88888878 47403a6d a0d306be ...
# 3299801  <e6100000 010c8888 88888878 47403a6d a0d306be ...
# 3299802  <e6100000 010c8888 88888878 47403a6d a0d306be ...
# 3299803  <e6100000 010c8888 88888878 47403a6d a0d306be ...
# 3299804  <e6100000 010c8888 88888878 47403a6d a0d306be ...
#
# [3299805 rows x 57 columns]

# %%
#Checking columns
data2018.columns
# Out:
# Index(['HistoricalReservationID', 'OrderNumber', 'Agency', 'OrgID',
#        'CodeHierarchy', 'RegionCode', 'RegionDescription', 'ParentLocationID',
#        'ParentLocation', 'LegacyFacilityID', 'Park', 'SiteType', 'UseType',
#        'ProductID', 'EntityType', 'EntityID', 'FacilityID', 'FacilityZIP',
#        'FacilityState', 'FacilityLongitude', 'FacilityLatitude', 'CustomerZIP',
#        'CustomerState', 'CustomerCountry', 'Tax', 'UseFee', 'TranFee',
#        'AttrFee', 'TotalBeforeTax', 'TotalPaid', 'StartDate', 'EndDate',
#        'OrderDate', 'NumberOfPeople', 'Tent', 'Popup', 'Trailer',
#        'RVMotorhome', 'Boat', 'HorseTrailer', 'Car', 'FifthWheel', 'Van',
#        'CanoeKayak', 'BoatTrailer', 'Motorcycle', 'Truck', 'Bus', 'Bicycle',
#        'Snowmobile', 'OffRoadlAllTerrainVehicle', 'PowerBoat', 'PickupCamper',
#        'LargeTentOver9x12', 'SmallTent', 'Marinaboat', 'LatLongPoint'],
#       dtype='object')

# %%
#Choosing only West Coast states data
data2018_WestCoast = data2018.loc[(data2018["FacilityState"] == "Oregon") |
                                  (data2018["FacilityState"] == "OR") |
                                  (data2018["FacilityState"] == "Washington") |
                                  (data2018["FacilityState"] == "WA") |
                                  (data2018["FacilityState"] == "California") |
                                  (data2018["FacilityState"] == "CA")]

# %%
#For the purposes of the project we interested only in reservable overnight campsites, but the reservation data also 
#included other types of camgrounds services
data2018_WestCoast["UseType"].unique()
# Out:
# array(['Overnight', 'Day', nan, 'OverNight'], dtype=object)

# %%
data2018_WestCoast["EntityType"].unique()
# Out:
# array(['Site', 'ERR', 'Tour'], dtype=object)

# %%
#Choosing only reservable overnight campsites
data2018_WestCoast_clean = data2018_WestCoast.loc[((data2018_WestCoast["UseType"] == "Overnight") 
                                                 | (data2018_WestCoast["UseType"] == "OverNight"))
                                                 & (data2018_WestCoast["EntityType"] == "Site")]

# %%
#Dropping unnecessary columns
data2018_WestCoast_clean = data2018_WestCoast_clean.drop(columns=['HistoricalReservationID', 
       'OrderNumber', 'OrgID', 'CodeHierarchy', 'RegionCode', 'ParentLocationID',
       'LegacyFacilityID', 'UseType', 'ProductID', 'EntityType', 'EntityID',
       'FacilityLongitude', 'FacilityLatitude', 'Tax', 'UseFee', 'TranFee',
       'AttrFee', 'TotalPaid', 'Tent', 'Popup', 'Trailer',
       'RVMotorhome', 'Boat', 'HorseTrailer', 'Car', 'FifthWheel', 'Van',
       'CanoeKayak', 'BoatTrailer', 'Motorcycle', 'Truck', 'Bus', 'Bicycle',
       'Snowmobile', 'OffRoadlAllTerrainVehicle', 'PowerBoat', 'PickupCamper',
       'LargeTentOver9x12', 'SmallTent', 'Marinaboat', 'LatLongPoint'])

# %%
#Checking datatypes for future manipulations
data2018_WestCoast_clean.dtypes
# Out:
# Agency                object
# RegionDescription     object
# ParentLocation        object
# Park                  object
# SiteType              object
# FacilityID           float64
# FacilityZIP           object
# FacilityState         object
# CustomerZIP           object
# CustomerState         object
# CustomerCountry       object
# TotalBeforeTax       float64
# StartDate             object
# EndDate               object
# OrderDate             object
# NumberOfPeople       float64
# dtype: object

# %%
#Converting dates to datetime data type with purpose extract data for the camping season (May 1 - September 30)
data2018_WestCoast_clean["StartDate"] = pd.to_datetime(data2018_WestCoast_clean["StartDate"])
data2018_WestCoast_clean["EndDate"] = pd.to_datetime(data2018_WestCoast_clean["EndDate"])
data2018_WestCoast_clean["OrderDate"] = pd.to_datetime(data2018_WestCoast_clean["OrderDate"])

# %%
#Checking the success of converting the date data
data2018_WestCoast_clean.dtypes
# Out:
# Agency                       object
# RegionDescription            object
# ParentLocation               object
# Park                         object
# SiteType                     object
# FacilityID                  float64
# FacilityZIP                  object
# FacilityState                object
# CustomerZIP                  object
# CustomerState                object
# CustomerCountry              object
# TotalBeforeTax              float64
# StartDate            datetime64[ns]
# EndDate              datetime64[ns]
# OrderDate            datetime64[ns]
# NumberOfPeople              float64
# dtype: object

# %%
#Extracting camping season data
data2018_WestCoast_clean = data2018_WestCoast_clean.loc[(data2018_WestCoast_clean["StartDate"] >= "2018-05-01") 
                                                      & (data2018_WestCoast_clean["EndDate"] <= "2018-09-30")]
data2018_WestCoast_clean
# Out:
#         Agency   RegionDescription    ParentLocation  \
# 3200      USFS   GEORGETOWN RD -FS  ELDORADO NF - FS
# 3201      USFS   GEORGETOWN RD -FS  ELDORADO NF - FS
# 3202      USFS   GEORGETOWN RD -FS  ELDORADO NF - FS
# 3203      USFS   GEORGETOWN RD -FS  ELDORADO NF - FS
# 3204      USFS   GEORGETOWN RD -FS  ELDORADO NF - FS
# ...        ...                 ...               ...
# 3299469   USFS  HOOD CANAL RD - FS   OLYMPIC NF - FS
# 3299470   USFS  HOOD CANAL RD - FS   OLYMPIC NF - FS
# 3299471   USFS  HOOD CANAL RD - FS   OLYMPIC NF - FS
# 3299472   USFS  HOOD CANAL RD - FS   OLYMPIC NF - FS
# 3299473   USFS  HOOD CANAL RD - FS   OLYMPIC NF - FS
#
#                                  Park                    SiteType  FacilityID  \
# 3200       Middle Meadows --- FPIN151  GROUP STANDARD NONELECTRIC    231953.0
# 3201       Middle Meadows --- FPIN151  GROUP STANDARD NONELECTRIC    231953.0
# 3202       Middle Meadows --- FPIN151  GROUP STANDARD NONELECTRIC    231953.0
# 3203       Middle Meadows --- FPIN151  GROUP STANDARD NONELECTRIC    231953.0
# 3204       Middle Meadows --- FPIN151  GROUP STANDARD NONELECTRIC    231953.0
# ...                               ...                         ...         ...
# 3299469  Coho Campground --- FPIN2427                        YURT    233384.0
# 3299470  Coho Campground --- FPIN2427                        YURT    233384.0
# 3299471  Coho Campground --- FPIN2427                        YURT    233384.0
# 3299472  Coho Campground --- FPIN2427                        YURT    233384.0
# 3299473  Coho Campground --- FPIN2427                        YURT    233384.0
#
#         FacilityZIP FacilityState CustomerZIP CustomerState CustomerCountry  \
# 3200          95634            CA       89521            NV             USA
# 3201          95634            CA       95616            CA             USA
# 3202          95634            CA       95823            CA             USA
# 3203          95634            CA       93245            CA             USA
# 3204          95634            CA  95660-4137            CA             USA
# ...             ...           ...         ...           ...             ...
# 3299469       98376            WA       98166            WA             USA
# 3299470       98376            WA       98509            WA             USA
# 3299471       98376            WA       59602            MT             USA
# 3299472       98376            WA       98109            WA             USA
# 3299473       98376            WA       97302            OR             USA
#
#          TotalBeforeTax  StartDate    EndDate  OrderDate  NumberOfPeople
# 3200              135.0 2018-07-04 2018-07-09 2017-10-02            50.0
# 3201               20.0 2018-05-11 2018-05-13 2017-11-11            50.0
# 3202               20.0 2018-06-22 2018-06-24 2017-11-15            50.0
# 3203              185.0 2018-06-24 2018-07-01 2017-11-24            50.0
# 3204               85.0 2018-06-15 2018-06-18 2017-12-13            50.0
# ...                 ...        ...        ...        ...             ...
# 3299469            80.0 2018-08-09 2018-08-10 2018-08-04             4.0
# 3299470            80.0 2018-08-15 2018-08-16 2018-08-09             2.0
# 3299471            80.0 2018-08-19 2018-08-20 2018-08-12             6.0
# 3299472            80.0 2018-09-02 2018-09-03 2018-08-17             2.0
# 3299473           220.0 2018-09-16 2018-09-19 2018-09-06             2.0
#
# [582710 rows x 16 columns]

# %%
#Reading the data for 2019
data2019 = pd.read_csv("../../Resources/data/reservations2019.csv", encoding= 'unicode_escape')
data2019
# Out:
# D:\anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3072: DtypeWarning: Columns (5,6,7,12,17,20,31,34) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                       historicalreservationid   ordernumber agency  orgid  \
# 0        9c4a5398-4b50-4aa6-92fe-9a32699e49f9  0100084620-1    BLM  126.0
# 1        4018a5bb-7e8a-49a1-bea2-f86be53b16e0  0100162496-1    BLM  126.0
# 2        6458d681-584b-4e2b-b3f9-f398fa28f9eb  0100328335-1    BLM  126.0
# 3        c4b1f737-44b8-46ca-ada4-523fe74a199c  0100404611-1    BLM  126.0
# 4        e4f54fd0-2739-44a1-b807-bba4e3584e4a  0100444692-1    BLM  126.0
# ...                                       ...           ...    ...    ...
# 3479638                           4-4609121-1   4-4609121-1    NaN    NaN
# 3479639                           4-4618681-1   4-4618681-1    NaN    NaN
# 3479640                           4-4626415-1   4-4626415-1    NaN    NaN
# 3479641                           4-4628875-1   4-4628875-1    NaN    NaN
# 3479642                           4-4635424-1   4-4635424-1    NaN    NaN
#
#                        codehierarchy regioncode regiondescription  \
# 0        |1|70901|72193|72194|146090         AK      Alaska (BLM)
# 1        |1|70901|72193|72194|146090         AK      Alaska (BLM)
# 2        |1|70901|72193|72194|146090         AK      Alaska (BLM)
# 3        |1|70901|72193|72194|146090         AK      Alaska (BLM)
# 4        |1|70901|72193|72194|146090         AK      Alaska (BLM)
# ...                              ...        ...               ...
# 3479638                          NaN        NaN               NaN
# 3479639                          NaN        NaN               NaN
# 3479640                          NaN        NaN               NaN
# 3479641                          NaN        NaN               NaN
# 3479642                          NaN        NaN               NaN
#
#         parentlocationid                            parentlocation  \
# 0                  72195  White Mountains National Recreation Area
# 1                  72195  White Mountains National Recreation Area
# 2                  72195  White Mountains National Recreation Area
# 3                  72195  White Mountains National Recreation Area
# 4                  72195  White Mountains National Recreation Area
# ...                  ...                                       ...
# 3479638              NaN                                       NaN
# 3479639              NaN                                       NaN
# 3479640              NaN                                       NaN
# 3479641              NaN                                       NaN
# 3479642              NaN                                       NaN
#
#          legacyfacilityid  ... attrfee totalbeforetax discount  totalpaid  \
# 0                146090.0  ...     NaN           33.0      0.0       33.0
# 1                146090.0  ...     NaN           18.0      0.0       18.0
# 2                146090.0  ...     NaN           33.0      0.0       33.0
# 3                146090.0  ...     NaN           58.0      0.0       58.0
# 4                146090.0  ...     NaN           33.0      0.0       33.0
# ...                   ...  ...     ...            ...      ...        ...
# 3479638               NaN  ...     NaN            6.0      0.0        6.0
# 3479639               NaN  ...     NaN            4.0      0.0        4.0
# 3479640               NaN  ...     NaN            4.0      0.0        4.0
# 3479641               NaN  ...     NaN           47.0      0.0       47.0
# 3479642               NaN  ...     NaN            3.0      0.0        3.0
#
#                    startdate              enddate                orderdate  \
# 0        2019-01-26 00:00:00  2019-01-27 00:00:00  2018-12-27 20:54:55.233
# 1        2019-03-26 00:00:00  2019-03-27 00:00:00  2019-02-24 15:00:45.718
# 2        2019-08-26 00:00:00  2019-08-27 00:00:00  2019-08-26 17:06:23.052
# 3        2018-11-23 00:00:00  2018-11-25 00:00:00  2018-10-23 00:23:58.275
# 4        2019-08-28 00:00:00  2019-08-29 00:00:00  2019-08-15 18:33:22.488
# ...                      ...                  ...                      ...
# 3479638  2018-11-02 00:00:00                  NaN      2019-10-01 00:00:00
# 3479639  2018-11-04 00:00:00                  NaN      2019-10-01 00:00:00
# 3479640  2018-11-20 00:00:00                  NaN      2019-10-01 00:00:00
# 3479641  2018-12-08 00:00:00                  NaN      2019-10-01 00:00:00
# 3479642  2018-11-02 00:00:00                  NaN      2019-10-01 00:00:00
#
#         numberofpeople  equipmentdescription  equipmentlength
# 0                  4.0                   NaN              0.0
# 1                  1.0                   NaN              0.0
# 2                  2.0                   NaN              0.0
# 3                  5.0                   NaN              0.0
# 4                  2.0                   NaN              0.0
# ...                ...                   ...              ...
# 3479638            6.0                   NaN              NaN
# 3479639            4.0                   NaN              NaN
# 3479640            4.0                   NaN              NaN
# 3479641           47.0                   NaN              NaN
# 3479642            3.0                   NaN              NaN
#
# [3479643 rows x 36 columns]

# %%
#Checking columns
data2019.columns
# Out:
# Index(['historicalreservationid', 'ordernumber', 'agency', 'orgid',
#        'codehierarchy', 'regioncode', 'regiondescription', 'parentlocationid',
#        'parentlocation', 'legacyfacilityid', 'park', 'sitetype', 'usetype',
#        'productid', 'inventorytype', 'facilityid', 'facilityzip',
#        'facilitystate', 'facilitylongitude', 'facilitylatitude', 'customerzip',
#        'customerstate', 'customercountry', 'tax', 'usefee', 'tranfee',
#        'attrfee', 'totalbeforetax', 'discount', 'totalpaid', 'startdate',
#        'enddate', 'orderdate', 'numberofpeople', 'equipmentdescription',
#        'equipmentlength'],
#       dtype='object')

# %%
#Choosing only West Coast states data
data2019_WestCoast = data2019.loc[(data2019["facilitystate"] == "Oregon") |
                                  (data2019["facilitystate"] == "OR") |
                                  (data2019["facilitystate"] == "Washington") |
                                  (data2019["facilitystate"] == "WA") |
                                  (data2019["facilitystate"] == "California") |
                                  (data2019["facilitystate"] == "CA")]

# %%
#For the purposes of the project we interested only in reservable overnight campsites, but the reservation data also 
#included other types of camgrounds services
data2019_WestCoast["usetype"].unique()
# Out:
# array([nan, 'Overnight', 'Day'], dtype=object)

# %%
data2019_WestCoast["inventorytype"].unique()
# Out:
# array(['TICKET', 'VEHICLE_PERMIT', 'PERMIT', 'CAMPING', 'LOTTERY_PERMIT',
#        'LOTTERY_CAMPING'], dtype=object)

# %%
#Choosing only reservable overnight campsites
data2019_WestCoast_clean = data2019_WestCoast.loc[((data2019["usetype"] == "Overnight") 
                                                 | (data2019_WestCoast["usetype"] == "Multi"))
                                                & ((data2019_WestCoast["inventorytype"] == "CAMPING") 
                                                 | (data2019_WestCoast["inventorytype"] == "LOTTERY_CAMPING"))]

# %%
#Dropping unnecessary columns
data2019_WestCoast_clean = data2019_WestCoast_clean.drop(columns=['historicalreservationid', 'ordernumber', 'orgid',
       'codehierarchy', 'regioncode', 'parentlocationid', 'legacyfacilityid', 'usetype',
       'productid', 'inventorytype', 'facilitylongitude', 'facilitylatitude', 'tax', 'usefee', 'tranfee',
       'attrfee', 'discount', 'totalpaid', 'equipmentdescription',
       'equipmentlength'])

# %%
#Checking datatypes for future manipulations
data2019_WestCoast_clean.dtypes
# Out:
# agency                object
# regiondescription     object
# parentlocation        object
# park                  object
# sitetype              object
# facilityid             int64
# facilityzip          float64
# facilitystate         object
# customerzip           object
# customerstate         object
# customercountry       object
# totalbeforetax       float64
# startdate             object
# enddate               object
# orderdate             object
# numberofpeople       float64
# dtype: object

# %%
#Converting dates to datetime data type with purpose extract data for the camping season (May 1 - September 30)
data2019_WestCoast_clean["startdate"] = pd.to_datetime(data2019_WestCoast_clean["startdate"])
data2019_WestCoast_clean["enddate"] = pd.to_datetime(data2019_WestCoast_clean["enddate"])
data2019_WestCoast_clean["orderdate"] = pd.to_datetime(data2019_WestCoast_clean["orderdate"])

# %%
#Checking the success of converting the date data
data2019_WestCoast_clean.dtypes
# Out:
# agency                       object
# regiondescription            object
# parentlocation               object
# park                         object
# sitetype                     object
# facilityid                    int64
# facilityzip                 float64
# facilitystate                object
# customerzip                  object
# customerstate                object
# customercountry              object
# totalbeforetax              float64
# startdate            datetime64[ns]
# enddate              datetime64[ns]
# orderdate            datetime64[ns]
# numberofpeople              float64
# dtype: object

# %%
#Extracting camping season data
data2019_WestCoast_clean = data2019_WestCoast_clean.loc[(data2019_WestCoast_clean["startdate"] >= "2019-05-01") 
                                                      & (data2019_WestCoast_clean["enddate"] <= "2019-09-30")]
data2019_WestCoast_clean
# Out:
#         agency regiondescription                       parentlocation  \
# 14540      BLM      Oregon (BLM)  North Umpqua Wild and Scenic River
# 14541      BLM      Oregon (BLM)  North Umpqua Wild and Scenic River
# 14542      BLM      Oregon (BLM)  North Umpqua Wild and Scenic River
# 14543      BLM      Oregon (BLM)  North Umpqua Wild and Scenic River
# 14544      BLM      Oregon (BLM)  North Umpqua Wild and Scenic River
# ...        ...               ...                                  ...
# 3479460   USFS               NaN                                  NaN
# 3479461   USFS               NaN                                  NaN
# 3479462   USFS               NaN                                  NaN
# 3479463   USFS               NaN                                  NaN
# 3479464   USFS               NaN                                  NaN
#
#                                              park              sitetype  \
# 14540    Eagleview Group Campground (Reservation)     GROUP PICNIC AREA
# 14541    Eagleview Group Campground (Reservation)     GROUP PICNIC AREA
# 14542    Eagleview Group Campground (Reservation)     GROUP PICNIC AREA
# 14543    Eagleview Group Campground (Reservation)     GROUP PICNIC AREA
# 14544    Eagleview Group Campground (Reservation)     GROUP PICNIC AREA
# ...                                           ...                   ...
# 3479460          HAYSTACK CAMPGROUND (EAST SHORE)  STANDARD NONELECTRIC
# 3479461          HAYSTACK CAMPGROUND (EAST SHORE)  STANDARD NONELECTRIC
# 3479462          HAYSTACK CAMPGROUND (EAST SHORE)  STANDARD NONELECTRIC
# 3479463          HAYSTACK CAMPGROUND (EAST SHORE)  STANDARD NONELECTRIC
# 3479464          HAYSTACK CAMPGROUND (EAST SHORE)  STANDARD NONELECTRIC
#
#          facilityid  facilityzip facilitystate customerzip customerstate  \
# 14540        233153      97462.0        Oregon         NaN           NaN
# 14541        233153      97462.0        Oregon       97321            OR
# 14542        233153      97462.0        Oregon         NaN           NaN
# 14543        233153      97462.0        Oregon         NaN           NaN
# 14544        233153      97462.0        Oregon       97210            OR
# ...             ...          ...           ...         ...           ...
# 3479460      234779      97734.0        Oregon       97471           NaN
# 3479461      234779      97734.0        Oregon       97471           NaN
# 3479462      234779      97734.0        Oregon         NaN           NaN
# 3479463      234779      97734.0        Oregon       98446            WA
# 3479464      234779      97734.0        Oregon       98446            WA
#
#         customercountry  totalbeforetax  startdate    enddate  \
# 14540               NaN             0.0 2019-05-31 2019-06-02
# 14541               USA           153.0 2019-07-28 2019-07-29
# 14542               NaN             8.0 2019-09-13 2019-09-16
# 14543               NaN           598.0 2019-09-02 2019-09-24
# 14544               USA           298.0 2019-08-04 2019-08-06
# ...                 ...             ...        ...        ...
# 3479460             NaN            53.0 2019-07-25 2019-07-28
# 3479461             NaN            53.0 2019-07-25 2019-07-28
# 3479462             NaN            38.0 2019-07-12 2019-07-14
# 3479463             USA            23.0 2019-08-30 2019-08-31
# 3479464             USA            18.0 2019-08-30 2019-09-02
#
#                       orderdate  numberofpeople
# 14540   2019-01-02 02:34:22.705            75.0
# 14541   2019-01-26 19:44:15.325           100.0
# 14542   2018-10-31 19:47:28.666           100.0
# 14543   2019-02-21 05:51:32.858            50.0
# 14544   2019-02-26 01:06:30.684            20.0
# ...                         ...             ...
# 3479460 2019-04-26 02:36:20.224             6.0
# 3479461 2019-04-26 02:36:20.224             6.0
# 3479462 2019-05-13 04:25:42.686             3.0
# 3479463 2019-04-10 02:28:52.698             3.0
# 3479464 2019-04-10 02:28:52.698             4.0
#
# [632409 rows x 16 columns]

# %%
#Reading the data for 2020
data2020 = pd.read_csv("../../Resources/data/reservations2020.csv", encoding= 'unicode_escape')
data2020
# Out:
# D:\anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3072: DtypeWarning: Columns (5,6,7,11,12,13,15,17,35) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                       historicalreservationid   ordernumber agency  orgid  \
# 0        fa50401c-f08a-4738-b576-56335cc19cb7  0121072064-1    BLM    126
# 1        09c37303-cf15-49d9-9b0c-ccc120328bbb  0200063847-1    BLM    126
# 2        f1f5c841-46b1-4ff8-a6dc-fcac2e76ae1c  0200087454-1    BLM    126
# 3        619f4394-1cac-4a64-8f0c-eae6e7f6bf3b  0200102788-1    BLM    126
# 4        82674243-7f31-41e6-b3db-d0690513cad3  0200147542-1    BLM    126
# ...                                       ...           ...    ...    ...
# 5114784  3dc6db19-e935-11ea-b093-0a4663ab7691  0299936603-1   USFS    131
# 5114785  31aa3a26-bf9f-11ea-9be3-ae918ba7a17b  0299948467-1   USFS    131
# 5114786  abdea1e5-bfd3-11ea-b504-127b1cc19b77  0299955580-1   USFS    131
# 5114787  8a06cee8-cd58-11ea-a075-5eeb99748ba8  0299963410-1   USFS    131
# 5114788  5b63b296-c051-11ea-aec3-62673053eda9  0299996835-1   USFS    131
#
#                        codehierarchy regioncode regiondescription  \
# 0        |1|70901|72193|72194|146090         AK      Alaska (BLM)
# 1        |1|70901|72193|72194|146090         AK      Alaska (BLM)
# 2        |1|70901|72193|72194|146090         AK      Alaska (BLM)
# 3        |1|70901|72193|72194|146090         AK      Alaska (BLM)
# 4        |1|70901|72193|72194|146090         AK      Alaska (BLM)
# ...                              ...        ...               ...
# 5114784              |1|70903|300017        NaN               NaN
# 5114785              |1|70903|300017        NaN               NaN
# 5114786              |1|70903|300017        NaN               NaN
# 5114787              |1|70903|300017        NaN               NaN
# 5114788              |1|70903|300017        NaN               NaN
#
#         parentlocationid                            parentlocation  \
# 0                  72195  White Mountains National Recreation Area
# 1                  72195  White Mountains National Recreation Area
# 2                  72195  White Mountains National Recreation Area
# 3                  72195  White Mountains National Recreation Area
# 4                  72195  White Mountains National Recreation Area
# ...                  ...                                       ...
# 5114784            14487                 El Yunque National Forest
# 5114785            14487                 El Yunque National Forest
# 5114786            14487                 El Yunque National Forest
# 5114787            14487                 El Yunque National Forest
# 5114788            14487                 El Yunque National Forest
#
#          legacyfacilityid  ... totalbeforetax discount totalpaid  \
# 0                146090.0  ...           33.0      0.0      33.0
# 1                146090.0  ...           33.0      0.0      33.0
# 2                146090.0  ...           83.0      0.0      83.0
# 3                146090.0  ...           33.0      0.0      33.0
# 4                146090.0  ...            0.0      0.0       0.0
# ...                   ...  ...            ...      ...       ...
# 5114784               NaN  ...            4.0      0.0       4.0
# 5114785               NaN  ...            2.0      0.0       2.0
# 5114786               NaN  ...            2.0      0.0       2.0
# 5114787               NaN  ...            2.0      0.0       2.0
# 5114788               NaN  ...            2.0      0.0       2.0
#
#                    startdate              enddate                orderdate  \
# 0        2019-10-17 00:00:00  2019-10-18 00:00:00   2019-09-18 16:25:42.28
# 1        2020-04-11 00:00:00  2020-04-12 00:00:00  2020-03-13 16:35:11.612
# 2        2020-09-07 00:00:00  2020-09-10 00:00:00  2020-08-17 05:19:08.159
# 3        2020-03-21 00:00:00  2020-03-22 00:00:00  2020-02-20 15:01:33.904
# 4        2019-12-07 00:00:00  2019-12-08 00:00:00  2019-11-07 17:54:01.448
# ...                      ...                  ...                      ...
# 5114784  2020-09-05 00:00:00  2020-09-05 00:00:00  2020-08-28 13:49:44.115
# 5114785  2020-07-17 00:00:00  2020-07-17 00:00:00   2020-07-06 15:43:44.14
# 5114786  2020-07-12 00:00:00  2020-07-12 00:00:00  2020-07-06 22:00:34.837
# 5114787  2020-07-30 00:00:00  2020-07-30 00:00:00  2020-07-24 02:52:17.583
# 5114788  2020-08-02 00:00:00  2020-08-02 00:00:00  2020-07-07 12:58:51.219
#
#            nights numberofpeople  equipmentdescription  equipmentlength
# 0           1 day            6.0                   NaN              0.0
# 1           1 day            1.0                   NaN              0.0
# 2          3 days            2.0                   NaN              0.0
# 3           1 day            3.0                   NaN              0.0
# 4           1 day            2.0                   NaN              0.0
# ...           ...            ...                   ...              ...
# 5114784  00:00:00            2.0                   NaN              NaN
# 5114785  00:00:00            1.0                   NaN              NaN
# 5114786  00:00:00            1.0                   NaN              NaN
# 5114787  00:00:00            0.0                   NaN              NaN
# 5114788  00:00:00            0.0                   NaN              NaN
#
# [5114789 rows x 37 columns]

# %%
#Checking columns
data2020.columns
# Out:
# Index(['historicalreservationid', 'ordernumber', 'agency', 'orgid',
#        'codehierarchy', 'regioncode', 'regiondescription', 'parentlocationid',
#        'parentlocation', 'legacyfacilityid', 'park', 'sitetype', 'usetype',
#        'productid', 'inventorytype', 'facilityid', 'facilityzip',
#        'facilitystate', 'facilitylongitude', 'facilitylatitude', 'customerzip',
#        'customerstate', 'customercountry', 'tax', 'usefee', 'tranfee',
#        'attrfee', 'totalbeforetax', 'discount', 'totalpaid', 'startdate',
#        'enddate', 'orderdate', 'nights', 'numberofpeople',
#        'equipmentdescription', 'equipmentlength'],
#       dtype='object')

# %%
#Choosing only West Coast states data
data2020_WestCoast = data2020.loc[(data2020["facilitystate"] == "Oregon") |
                                  (data2020["facilitystate"] == "OR") |
                                  (data2020["facilitystate"] == "Washington") |
                                  (data2020["facilitystate"] == "WA") |
                                  (data2020["facilitystate"] == "California") |
                                  (data2020["facilitystate"] == "CA")]

# %%
#For the purposes of the project we interested only in reservable overnight campsites, but the reservation data also 
#included other types of camgrounds services
data2020_WestCoast["usetype"].unique()
# Out:
# array([nan, 'Overnight', 'Day'], dtype=object)

# %%
data2020_WestCoast["inventorytype"].unique()
# Out:
# array(['TICKET', 'VEHICLE_PERMIT', 'PERMIT', 'CAMPING', 'LOTTERY_PERMIT'],
#       dtype=object)

# %%
#Choosing only reservable overnight campsites
data2020_WestCoast_clean = data2020_WestCoast.loc[(data2020_WestCoast["usetype"] == "Overnight") 
                                                & (data2020_WestCoast["inventorytype"] == "CAMPING")]

# %%
#Dropping unnecessary columns
data2020_WestCoast_clean = data2020_WestCoast_clean.drop(columns=['historicalreservationid', 'ordernumber', 'orgid',
       'codehierarchy', 'regioncode', 'parentlocationid', 'legacyfacilityid', 'usetype',
       'productid', 'inventorytype', 'facilitylongitude', 'facilitylatitude', 'tax', 'usefee', 'tranfee',
       'attrfee', 'discount', 'totalpaid', 'nights', 'equipmentdescription', 'equipmentlength'])

# %%
#Checking datatypes for future manipulations
data2020_WestCoast_clean.dtypes
# Out:
# agency                object
# regiondescription     object
# parentlocation        object
# park                  object
# sitetype              object
# facilityid            object
# facilityzip          float64
# facilitystate         object
# customerzip           object
# customerstate         object
# customercountry       object
# totalbeforetax       float64
# startdate             object
# enddate               object
# orderdate             object
# numberofpeople       float64
# dtype: object

# %%
#Converting dates to datetime data type with purpose extract data for the camping season (May 1 - September 30)
data2020_WestCoast_clean["startdate"] = pd.to_datetime(data2020_WestCoast_clean["startdate"])
data2020_WestCoast_clean["enddate"] = pd.to_datetime(data2020_WestCoast_clean["enddate"])
data2020_WestCoast_clean["orderdate"] = pd.to_datetime(data2020_WestCoast_clean["orderdate"])

# %%
#Checking the success of converting the date data
data2020_WestCoast_clean.dtypes
# Out:
# agency                       object
# regiondescription            object
# parentlocation               object
# park                         object
# sitetype                     object
# facilityid                   object
# facilityzip                 float64
# facilitystate                object
# customerzip                  object
# customerstate                object
# customercountry              object
# totalbeforetax              float64
# startdate            datetime64[ns]
# enddate              datetime64[ns]
# orderdate            datetime64[ns]
# numberofpeople              float64
# dtype: object

# %%
#Extracting camping season data
data2020_WestCoast_clean = data2020_WestCoast_clean.loc[(data2020_WestCoast_clean["startdate"] >= "2020-05-01") 
                                                      & (data2020_WestCoast_clean["enddate"] <= "2020-09-30")]
data2020_WestCoast_clean
# Out:
#         agency  regiondescription                       parentlocation  \
# 22636      BLM       Oregon (BLM)  North Umpqua Wild and Scenic River
# 22637      BLM       Oregon (BLM)  North Umpqua Wild and Scenic River
# 22638      BLM       Oregon (BLM)  North Umpqua Wild and Scenic River
# 22639      BLM       Oregon (BLM)  North Umpqua Wild and Scenic River
# 22640      BLM       Oregon (BLM)  North Umpqua Wild and Scenic River
# ...        ...                ...                                  ...
# 4712272   USFS  Pacific Northwest   Okanogan-Wenatchee National Forest
# 4712273   USFS  Pacific Northwest   Okanogan-Wenatchee National Forest
# 4712274   USFS  Pacific Northwest   Okanogan-Wenatchee National Forest
# 4712275   USFS  Pacific Northwest   Okanogan-Wenatchee National Forest
# 4712276   USFS  Pacific Northwest   Okanogan-Wenatchee National Forest
#
#                                              park              sitetype  \
# 22636    Eagleview Group Campground (Reservation)     GROUP PICNIC AREA
# 22637    Eagleview Group Campground (Reservation)     GROUP PICNIC AREA
# 22638    Eagleview Group Campground (Reservation)     GROUP PICNIC AREA
# 22639    Eagleview Group Campground (Reservation)     GROUP PICNIC AREA
# 22640    Eagleview Group Campground (Reservation)     GROUP PICNIC AREA
# ...                                           ...                   ...
# 4712272      Lake Creek Campground - Entiat River  STANDARD NONELECTRIC
# 4712273      Lake Creek Campground - Entiat River  STANDARD NONELECTRIC
# 4712274      Lake Creek Campground - Entiat River  STANDARD NONELECTRIC
# 4712275      Lake Creek Campground - Entiat River  STANDARD NONELECTRIC
# 4712276      Lake Creek Campground - Entiat River  STANDARD NONELECTRIC
#
#         facilityid  facilityzip facilitystate customerzip customerstate  \
# 22636       233153      97462.0        Oregon         NaN           NaN
# 22637       233153      97462.0        Oregon       97477            OR
# 22638       233153      97462.0        Oregon       97420            OR
# 22639       233153      97462.0        Oregon         NaN           NaN
# 22640       233153      97462.0        Oregon         NaN           NaN
# ...            ...          ...           ...         ...           ...
# 4712272     273975      98822.0    Washington       98117            WA
# 4712273     273975      98822.0    Washington         NaN           NaN
# 4712274     273975      98822.0    Washington       98801            WA
# 4712275     273975      98822.0    Washington       98006            WA
# 4712276     273975      98822.0    Washington       98801            WA
#
#         customercountry  totalbeforetax  startdate    enddate  \
# 22636               NaN             0.0 2020-07-23 2020-07-29
# 22637               USA             0.0 2020-07-19 2020-07-23
# 22638               USA             0.0 2020-08-09 2020-08-17
# 22639               NaN             0.0 2020-08-01 2020-08-06
# 22640               NaN            18.0 2020-08-20 2020-08-24
# ...                 ...             ...        ...        ...
# 4712272             USA            28.0 2020-08-14 2020-08-16
# 4712273             NaN            18.0 2020-07-02 2020-07-03
# 4712274             USA           108.0 2020-07-07 2020-07-17
# 4712275             USA            38.0 2020-08-06 2020-08-09
# 4712276             USA            18.0 2020-07-20 2020-07-24
#
#                       orderdate  numberofpeople
# 22636   2019-07-23 14:01:57.903            15.0
# 22637   2019-07-20 02:08:30.961            22.0
# 22638   2019-08-10 00:16:02.951           100.0
# 22639   2019-08-27 19:39:13.162            30.0
# 22640   2019-08-21 06:02:41.910           100.0
# ...                         ...             ...
# 4712272 2020-08-10 18:14:43.334             2.0
# 4712273 2020-06-30 06:08:40.328             1.0
# 4712274 2020-07-02 16:31:16.374             2.0
# 4712275 2020-07-20 23:16:45.644             8.0
# 4712276 2020-03-17 00:37:06.530             8.0
#
# [827463 rows x 16 columns]

# %%
#Connecting all data for 2016 - 2020
data2016_2018 = pd.concat([data2016_WestCoast_clean, data2017_WestCoast_clean, data2018_WestCoast_clean])
data2016_2018.columns
# Out:
# Index(['Agency', 'RegionDescription', 'ParentLocation', 'Park', 'SiteType',
#        'FacilityID', 'FacilityZIP', 'FacilityState', 'CustomerZIP',
#        'CustomerState', 'CustomerCountry', 'TotalBeforeTax', 'StartDate',
#        'EndDate', 'OrderDate', 'NumberOfPeople'],
#       dtype='object')

# %%
data2016_2018 = data2016_2018.rename(columns={'Agency':'agency', 
                                              'RegionDescription':'regiondescription',
                                              'ParentLocation':'parentlocation', 
                                              'Park':'park',
                                              'SiteType':'sitetype', 
                                              'FacilityID':'facilityid', 
                                              'FacilityZIP':'facilityzip', 
                                              'FacilityState':'facilitystate',
                                              'CustomerZIP':'customerzip', 
                                              'CustomerState':'customerstate', 
                                              'CustomerCountry':'customercountry', 
                                              'TotalBeforeTax':'totalbeforetax', 
                                              'StartDate':'startdate', 
                                              'EndDate':'enddate', 
                                              'OrderDate':'orderdate',
                                              'NumberOfPeople':'numberofpeople'})

# %%
data2016_2020 = pd.concat([data2016_2018, data2019_WestCoast_clean, data2020_WestCoast_clean])
data2016_2020
# Out:
#         agency          regiondescription                      parentlocation  \
# 48         NPS  Joshua Tree National Park                 Pacific West Region
# 96        USFS            MAMMOTH RD - FS                        INYO NF - FS
# 99        USFS  LOS ANGELES RIVER RD - FS                     ANGELES NF - FS
# 243       USFS             NACHES RD - FS         OKANOGAN - WENATCHEE NF -FS
# 274      USACE             LAKE MENDOCINO                  SAN FRANCISCO DIST
# ...        ...                        ...                                 ...
# 4712272   USFS          Pacific Northwest  Okanogan-Wenatchee National Forest
# 4712273   USFS          Pacific Northwest  Okanogan-Wenatchee National Forest
# 4712274   USFS          Pacific Northwest  Okanogan-Wenatchee National Forest
# 4712275   USFS          Pacific Northwest  Okanogan-Wenatchee National Forest
# 4712276   USFS          Pacific Northwest  Okanogan-Wenatchee National Forest
#
#                                          park  \
# 48                           SHEEP PASS GROUP
# 96                     PUMICE FLAT GROUP CAMP
# 99                    MEADOW GROUP CAMPGROUND
# 243                    SALMON COVE GROUP SITE
# 274                    BUSHAY RECREATION AREA
# ...                                       ...
# 4712272  Lake Creek Campground - Entiat River
# 4712273  Lake Creek Campground - Entiat River
# 4712274  Lake Creek Campground - Entiat River
# 4712275  Lake Creek Campground - Entiat River
# 4712276  Lake Creek Campground - Entiat River
#
#                                  sitetype facilityid facilityzip  \
# 48       GROUP TENT ONLY AREA NONELECTRIC     232470  92277-3597
# 96             GROUP STANDARD NONELECTRIC     231957       94301
# 99             GROUP STANDARD NONELECTRIC     233366         NaN
# 243       GROUP STANDARD AREA NONELECTRIC     234498       98937
# 274            GROUP STANDARD NONELECTRIC     233437  95482-9404
# ...                                   ...        ...         ...
# 4712272              STANDARD NONELECTRIC     273975       98822
# 4712273              STANDARD NONELECTRIC     273975       98822
# 4712274              STANDARD NONELECTRIC     273975       98822
# 4712275              STANDARD NONELECTRIC     273975       98822
# 4712276              STANDARD NONELECTRIC     273975       98822
#
#         facilitystate customerzip customerstate customercountry  \
# 48                 CA       90027            CA             USA
# 96                 CA       92301            CA             USA
# 99                 CA       91701            CA             USA
# 243                WA       98942            WA             USA
# 274                CA       94565            CA             USA
# ...               ...         ...           ...             ...
# 4712272    Washington       98117            WA             USA
# 4712273    Washington         NaN           NaN             NaN
# 4712274    Washington       98801            WA             USA
# 4712275    Washington       98006            WA             USA
# 4712276    Washington       98801            WA             USA
#
#          totalbeforetax  startdate    enddate               orderdate  \
# 48               100.00 2016-09-03 2016-09-05 2015-10-01 00:00:00.000
# 96               313.05 2016-06-30 2016-07-03 2015-10-01 00:00:00.000
# 99                81.00 2016-06-24 2016-06-26 2015-10-01 00:00:00.000
# 243              159.00 2016-09-08 2016-09-11 2015-10-01 00:00:00.000
# 274              705.00 2016-09-02 2016-09-05 2015-10-01 00:00:00.000
# ...                 ...        ...        ...                     ...
# 4712272           28.00 2020-08-14 2020-08-16 2020-08-10 18:14:43.334
# 4712273           18.00 2020-07-02 2020-07-03 2020-06-30 06:08:40.328
# 4712274          108.00 2020-07-07 2020-07-17 2020-07-02 16:31:16.374
# 4712275           38.00 2020-08-06 2020-08-09 2020-07-20 23:16:45.644
# 4712276           18.00 2020-07-20 2020-07-24 2020-03-17 00:37:06.530
#
#          numberofpeople
# 48                 20.0
# 96                 30.0
# 99                 24.0
# 243                27.0
# 274                40.0
# ...                 ...
# 4712272             2.0
# 4712273             1.0
# 4712274             2.0
# 4712275             8.0
# 4712276             8.0
#
# [3107706 rows x 16 columns]

# %%
data2016_2020.to_csv("../../Resources/data/reservations_West_Coast.csv", index = False, header=True)
