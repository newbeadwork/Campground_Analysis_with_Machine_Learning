# %%
import pandas as pd

# %%
data2019 = pd.read_csv("reservations_clean2019.csv", encoding= 'unicode_escape')
data2019
# Out:
# D:\anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3072: DtypeWarning: Columns (5) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#           ordernumber agency  orgid regioncode regiondescription  \
# 0        0100084620-1    BLM  126.0         AK      Alaska (BLM)
# 1        0100162496-1    BLM  126.0         AK      Alaska (BLM)
# 2        0100328335-1    BLM  126.0         AK      Alaska (BLM)
# 3        0100404611-1    BLM  126.0         AK      Alaska (BLM)
# 4        0100444692-1    BLM  126.0         AK      Alaska (BLM)
# ...               ...    ...    ...        ...               ...
# 2459659  0199632487-1   USFS  131.0        NaN               NaN
# 2459660  0199632487-2   USFS  131.0        NaN               NaN
# 2459661  0199808905-1   USFS  131.0        NaN               NaN
# 2459662  0199995863-1   USFS  131.0        NaN               NaN
# ...

# %%
data2020 = pd.read_csv("reservations_clean2020.csv", encoding= 'unicode_escape')
data2020
# Out:
# D:\anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3072: DtypeWarning: Columns (5) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#           ordernumber agency  orgid regioncode regiondescription  \
# 0        0121072064-1    BLM    126         AK      Alaska (BLM)
# 1        0200063847-1    BLM    126         AK      Alaska (BLM)
# 2        0200087454-1    BLM    126         AK      Alaska (BLM)
# 3        0200102788-1    BLM    126         AK      Alaska (BLM)
# 4        0200147542-1    BLM    126         AK      Alaska (BLM)
# ...               ...    ...    ...        ...               ...
# 3267185  0291749870-1   USFS    131         F9    Eastern Region
# 3267186  0292406044-1   USFS    131         F9    Eastern Region
# 3267187  0297477941-1   USFS    131         F9    Eastern Region
# 3267188  0297881857-1   USFS    131         F9    Eastern Region
# ...

# %%
data2019_2020 = pd.concat([data2019, data2020])
data2019_2020
# Out:
#           ordernumber agency  orgid regioncode regiondescription  \
# 0        0100084620-1    BLM  126.0         AK      Alaska (BLM)
# 1        0100162496-1    BLM  126.0         AK      Alaska (BLM)
# 2        0100328335-1    BLM  126.0         AK      Alaska (BLM)
# 3        0100404611-1    BLM  126.0         AK      Alaska (BLM)
# 4        0100444692-1    BLM  126.0         AK      Alaska (BLM)
# ...               ...    ...    ...        ...               ...
# 3267185  0291749870-1   USFS  131.0         F9    Eastern Region
# 3267186  0292406044-1   USFS  131.0         F9    Eastern Region
# 3267187  0297477941-1   USFS  131.0         F9    Eastern Region
# 3267188  0297881857-1   USFS  131.0         F9    Eastern Region
# 3267189  0299941449-1   USFS  131.0         F9    Eastern Region
#
#         parentlocationid                            parentlocation  \
# 0                  72195  White Mountains National Recreation Area
# ...

# %%
data2016_2018 = pd.read_csv("reservations_clean2016_2018.csv", encoding= 'unicode_escape')

# %%
data2019_2020.columns
# Out:
# Index(['ordernumber', 'agency', 'orgid', 'regioncode', 'regiondescription',
#        'parentlocationid', 'parentlocation', 'legacyfacilityid', 'park',
#        'sitetype', 'productid', 'facilityid', 'facilityzip', 'facilitystate',
#        'customerzip', 'customerstate', 'customercountry', 'tax',
#        'totalbeforetax', 'totalpaid', 'startdate', 'enddate', 'orderdate',
#        'numberofpeople'],
#       dtype='object')

# %%
data2016_2018.columns
# Out:
# Index(['OrderNumber', 'Agency', 'OrgID', 'RegionCode', 'RegionDescription',
#        'ParentLocationID', 'ParentLocation', 'LegacyFacilityID', 'Park',
#        'SiteType', 'ProductID', 'FacilityID', 'FacilityZIP', 'FacilityState',
#        'CustomerZIP', 'CustomerState', 'CustomerCountry', 'Tax',
#        'TotalBeforeTax', 'TotalPaid', 'StartDate', 'EndDate', 'OrderDate',
#        'NumberOfPeople'],
#       dtype='object')

# %%
data2016_2018 = data2016_2018.rename(columns={'OrderNumber':'ordernumber', 
                                              'Agency':'agency', 
                                              'OrgID':'orgid', 
                                              'RegionCode':'regioncode', 
                                              'RegionDescription':'regiondescription',
                                              'ParentLocationID':'parentlocationid', 
                                              'ParentLocation':'parentlocation', 
                                              'LegacyFacilityID':'legacyfacilityid', 
                                              'Park':'park',
                                              'SiteType':'sitetype', 
                                              'ProductID':'productid', 
                                              'FacilityID':'facilityid', 
                                              'FacilityZIP':'facilityzip', 
                                              'FacilityState':'facilitystate',
                                              'CustomerZIP':'customerzip', 
                                              'CustomerState':'customerstate', 
                                              'CustomerCountry':'customercountry', 
                                              'Tax':'tax',
                                              'TotalBeforeTax':'totalbeforetax', 
                                              'TotalPaid':'totalpaid', 
                                              'StartDate':'startdate', 
                                              'EndDate':'enddate', 
                                              'OrderDate':'orderdate',
                                              'NumberOfPeople':'numberofpeople'})

# %%
data2016_2020 = pd.concat([data2016_2018, data2019_2020])

# %%
data2016_2020.to_csv("reservations_clean2016_2020.csv", index = False, header=True)
