# %%
import pandas as pd

# %%
data_reservations = pd.read_csv("reservations_clean2016_2020.csv", encoding = 'unicode_escape')
# Out:
# D:\anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3072: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
len(data_reservations.index)
# Out:
# 10346943

# %%
data_reservations_West = data_reservations.loc[(data_reservations["facilitystate"] == "Oregon") |
                                                (data_reservations["facilitystate"] == "OR") |
                                                (data_reservations["facilitystate"] == "Washington") |
                                                (data_reservations["facilitystate"] == "WA") |
                                                (data_reservations["facilitystate"] == "California") |
                                                (data_reservations["facilitystate"] == "CA")]

# %%
len(data_reservations_West.index)
# Out:
# 3107706

# %%
data_reservations_West.groupby("facilitystate")["totalbeforetax"].sum()
# Out:
# facilitystate
# CA            6.083722e+07
# California    4.250647e+07
# OR            1.697824e+07
# Oregon        1.532756e+07
# WA            1.029091e+07
# Washington    9.264723e+06
# Name: totalbeforetax, dtype: float64

# %%
data_reservations_West
# Out:
#          agency          regiondescription  \
# 0           NPS  Joshua Tree National Park
# 1          USFS            MAMMOTH RD - FS
# 2          USFS  LOS ANGELES RIVER RD - FS
# 4          USFS             NACHES RD - FS
# 5         USACE             LAKE MENDOCINO
# ...         ...                        ...
# 10179220   USFS          Pacific Northwest
# 10179221   USFS          Pacific Northwest
# 10179222   USFS          Pacific Northwest
# 10179223   USFS          Pacific Northwest
# 10179224   USFS          Pacific Northwest
#
#                               parentlocation  \
# 0                        Pacific West Region
# 1                               INYO NF - FS
# 2                            ANGELES NF - FS
# 4                OKANOGAN - WENATCHEE NF -FS
# 5                         SAN FRANCISCO DIST
# ...                                      ...
# 10179220  Okanogan-Wenatchee National Forest
# 10179221  Okanogan-Wenatchee National Forest
# ...

# %%
data_reservations_West.to_csv("reservations_West_Coast.csv", index = False, header=True)
